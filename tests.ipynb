# %%
import pickle
from chem import collect
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# %%
from raman_density import RamanDensityObj
from utils import plot_ters_image

# %%
mp = np.load("test-pickle/mode835.94-alpha.mp.pickle")

dx = np.arange(-4.,4.32, 0.32)
dy = np.arange(-4, 4.32, 0.32)
gx, gy = np.meshgrid(dx,dy)

# %%
plt.contourf(mp.T, 200, cmap=plt.cm.jet)
plt.colorbar()
